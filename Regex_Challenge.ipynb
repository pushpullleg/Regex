# %% [markdown]
# ---
# ## Question 1: Extract Domain Names ⭐
#
# **Task:** Write a regex to extract just the domain names (without `www.` or `http://` or `https://`) from URLs.
#
# **Expected Output:** `['google.com', 'github.com', 'stackoverflow.com', 'example.org']`

# %%
import re

urls = [
    "https://www.google.com/search",
    "http://github.com/user/repo",
    "https://stackoverflow.com/questions/123",
    "www.example.org/page"
]

# Your regex pattern here
pattern = r""  # TODO

# Test it
for url in urls:
    match = re.search(pattern, url)
    print(match.group() if match else "No match")

# %% [markdown]
# ---
# ## Question 2: Validate Password Strength ⭐⭐
#
# **Task:** Create a regex that validates passwords with these rules:
# - At least 8 characters long
# - Contains at least one uppercase letter
# - Contains at least one lowercase letter
# - Contains at least one digit
# - Contains at least one special character (@, #, $, %, &)
#
# **Expected:** First 3 should match, last 2 should NOT match.

# %%
import re

passwords = [
    "Secure@123",      # Valid
    "MyP@ssw0rd",      # Valid
    "Strong#99",       # Valid
    "weakpass",        # Invalid (no uppercase, digit, special)
    "NOLOWER123@"      # Invalid (no lowercase)
]

# Your regex pattern here
pattern = r""  # TODO

# Test it
for pwd in passwords:
    if re.fullmatch(pattern, pwd):
        print(f"✓ {pwd} - Valid")
    else:
        print(f"✗ {pwd} - Invalid")

# %% [markdown]
# ---
# ## Question 3: Extract Hashtags ⭐
#
# **Task:** Extract all hashtags from social media text. Hashtags start with `#` and contain letters, numbers, and underscores (no spaces or special chars).
#
# **Expected Output:** `['#Python', '#regex', '#coding', '#AI_ML', '#2025trends']`

# %%
import re

text = "Learning #Python and #regex is fun! #coding #AI_ML tips for #2025trends. Not#valid but #valid_one is!"

# Your regex pattern here
pattern = r""  # TODO

# Test it
hashtags = re.findall(pattern, text)
print("Hashtags found:", hashtags)

# %% [markdown]
# ---
# ## Question 4: Parse Log Timestamps ⭐⭐
#
# **Task:** Extract timestamps in the format `YYYY-MM-DD HH:MM:SS` from log entries.
#
# **Expected Output:** `['2025-01-15 14:32:01', '2025-01-15 14:32:05', '2025-01-15 14:35:22']`

# %%
import re

logs = """
[2025-01-15 14:32:01] INFO: User logged in
[2025-01-15 14:32:05] WARNING: High memory usage
[2025-01-15 14:35:22] ERROR: Connection timeout
Some random text without timestamp
"""

# Your regex pattern here
pattern = r""  # TODO

# Test it
timestamps = re.findall(pattern, logs)
print("Timestamps:", timestamps)

# %% [markdown]
# ---
# ## Question 5: Redact Credit Card Numbers ⭐⭐
#
# **Task:** Find credit card numbers (16 digits, optionally separated by spaces or dashes in groups of 4) and replace them with `****-****-****-XXXX` (showing only last 4 digits).
#
# **Expected Output:** `"Cards: ****-****-****-5678 and ****-****-****-4321"`

# %%
import re

text = "Cards: 1234-5678-9012-5678 and 9876 5432 1098 4321"

# Your regex pattern and substitution here
pattern = r""  # TODO

def redact(match):
    # TODO: Extract last 4 digits and return redacted format
    pass

# Test it
redacted = re.sub(pattern, redact, text)
print(redacted)

# %% [markdown]
# ---
# ## Question 6: Extract IPv4 Addresses ⭐⭐
#
# **Task:** Extract valid IPv4 addresses. Each octet should be 0-255.
#
# **Expected Output:** `['192.168.1.1', '10.0.0.1', '255.255.255.0']` (exclude the invalid ones)

# %%
import re

text = "Servers: 192.168.1.1, 10.0.0.1, 999.999.999.999, 255.255.255.0, 256.1.1.1"

# Your regex pattern here (this is tricky - validate 0-255!)
pattern = r""  # TODO

# Test it
ips = re.findall(pattern, text)
print("Valid IPs:", ips)

# %% [markdown]
# ---
# ## Question 7: Remove HTML Tags ⭐
#
# **Task:** Strip all HTML tags from the text, keeping only the content.
#
# **Expected Output:** `"Hello World This is bold and italic text."`

# %%
import re

html = "<h1>Hello World</h1><p>This is <strong>bold</strong> and <em>italic</em> text.</p>"

# Your regex pattern here
pattern = r""  # TODO

# Test it
clean_text = re.sub(pattern, "", html)
print(clean_text)

# %% [markdown]
# ---
# ## Question 8: Find Repeated Words ⭐⭐
#
# **Task:** Find all cases where a word is immediately repeated (case-insensitive). Return the repeated word.
#
# **Expected Output:** `['the', 'is']`

# %%
import re

text = "This is is a test. The the cat sat on the mat."

# Your regex pattern here
pattern = r""  # TODO

# Test it
repeated = re.findall(pattern, text, re.IGNORECASE)
print("Repeated words:", repeated)

# %% [markdown]
# ---
# ## Question 9: Extract Prices ⭐⭐⭐
#
# **Task:** Extract all prices in formats: `$123`, `$1,234.56`, `USD 99.99`, `€50`, `£25.50`. Return just the numeric value with currency symbol.
#
# **Expected Output:** `['$99.99', '$1,234.56', 'USD 45', '€50', '£25.50']`

# %%
import re

text = "Items cost: $99.99, $1,234.56, USD 45, €50, and £25.50. Not a price: 100 or .99"

# Your regex pattern here
pattern = r""  # TODO

# Test it
prices = re.findall(pattern, text)
print("Prices:", prices)

# %% [markdown]
# ---
# ## Question 10: Split Camel Case ⭐⭐⭐
#
# **Task:** Convert camelCase or PascalCase variable names into space-separated words.
#
# **Examples:**
# - `getUserInfo` → `get User Info`
# - `XMLParser` → `XML Parser`
# - `iPhone12Pro` → `i Phone 12 Pro`
#
# **Expected Output:**
# ```
# get User Info
# XML Parser
# i Phone 12 Pro
# my Variable Name
# ```

# %%
import re

names = ["getUserInfo", "XMLParser", "iPhone12Pro", "myVariableName"]

# Your regex pattern here (hint: use lookaheads/lookbehinds for case transitions)
pattern = r""  # TODO

# Test it
for name in names:
    result = re.sub(pattern, r" ", name)
    print(result)

# %% [markdown]
# ---
# ## 🎉 Challenge Complete!
#
# Once you've attempted all questions, check your answers in `Regex_Challenge_Answers.ipynb`.
#
# **Scoring yourself:**
# - ⭐ Easy: 1 point each
# - ⭐⭐ Medium: 2 points each
# - ⭐⭐⭐ Hard: 3 points each
#
# **Max Score: 19 points**
#
# How did you do? 💪
